# %% [markdown]
# # Project: TMDb Movie Data Analysis
#
# ## Table of Contents
# <ul>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# > **First**: In this section, I will load in the data, then check for cleanliness, and then trim and clean your dataset for analysis. Make sure that I document our steps carefully and justify our cleaning decisions.
# ### General Properties

# %%
# Load dataset
df = pd.read_csv('tmdb-movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline      ...       \
# 0              The park is open.      ...
# 1             What a Lovely Day.      ...
# 2     One Choice Can Destroy You      ...
# 3  Every generation has a story.      ...
# 4            Vengeance Hits Home      ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %%
# same thing applies to `.tail()` which returns the last few rows
df.tail(1)
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
#                director                                       tagline  \
# 10865  Harold P. Warren  It's Shocking! It's Beyond Your Imagination!
#
#           ...                                                overview runtime  \
# 10865     ...       A family gets lost on the road and stumbles up...      74
#
#        genres production_companies release_date vote_count  vote_average  \
# 10865  Horror            Norm-Iris     11/15/66         15           1.5
#
#        release_year     budget_adj  revenue_adj
# 10865          1966  127642.279154          0.0
#
# [1 rows x 21 columns]

# %% [markdown]
# ### Data Cleaning (Similarty, Unusfel data And Missing values)
#
# >
# ><li>For the first two columns <code>id</code> and <code>imdb_id</code> seem that to be similar, and second one may not useful I will dispose <code>imdb_id</code> column.</li>
# >
# ><li><code>popularity</code>, <code>budget</code> and <code>revenue</code> appeared to be useful columns to give good information for our data but before that, but needing some tweaks like missing values. <code>release_date</code> and <code>release_year</code> columns to convert datetime object.</li>
# ><li><code>original_title</code>, <code>cast</code>, <code>director</code>, <code>runtime</code>, <code>genres</code>, <code>production_companies</code>, <code>vote_count</code>, columns may have very useful information for movies. Another colmuns will be dropping.</li>
# >
# ><li>Another colmuns as <code>imdb_id</code>, <code>keywords</code>, <code>overview</code>, <code>revenue_adj</code>, <code>budget_adj</code>, <code>homepage</code>, <code>vote_average</code>, <code>tagline</code>, <code>vote_count</code>, <code>vote_average</code>, <code>production_companies</code>, <code>director</code> and <code>cast</code> will be dropping.</li>

# %%
# check how many have elements of orihinal title column
df.original_title.nunique()
# Out:
# 10571

# %%
# analyze and drop Rows/Columns with Null values 
df = df.dropna()

# %%
# display data frame   dimensions
print('Data columns\t\tDatatype')
print('––––––––––––––––––––––––––––––––')
print(df.dtypes)
print('––––––––––––––––––––––––––––––––')
print("Dimensions of the dataframe: ({}) rows and ({}) columns".format(df.shape[0],df.shape[1]))
# Out:
# Data columns		Datatype
# ––––––––––––––––––––––––––––––––
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object
# ––––––––––––––––––––––––––––––––
# Dimensions of the dataframe: (1992) rows and (21) columns

# %%
# pritn number of duplicates in TMDB movies datasets
print(df.duplicated().sum())
# Out:
# 0

# %%
# drop duplicates TMDB movies datasets
df.drop_duplicates(inplace=True)

# %%
# drop columns unusing
df.drop(['imdb_id', 'keywords', 'overview', 'revenue_adj', 'budget_adj', 'homepage', 'vote_average', 'tagline'], axis=1, inplace=True)


print("After dropping columns: ({}) rows | ({}) columns".format(df.shape[0],df.shape[1]))
# Out:
# After dropping columns: (1992) rows | (13) columns

# %%
# check if there any missing values
print('DataColumns\t  MissingValues')
print('––––––––––––––––––––––––––––––––')
print(df.isna().sum())
print('––––––––––––––––––––––––––––––––')
print("({}) rows and ({}) columns".format(df.shape[0],df.shape[1]))
# Out:
# DataColumns	  MissingValues
# ––––––––––––––––––––––––––––––––
# id                      0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# director                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# release_year            0
# dtype: int64
# ––––––––––––––––––––––––––––––––
# (1992) rows and (13) columns

# %%
# display how many element which value equal Zero in budget column 
df[(df['budget'] == 0)].shape[0]
# Out:
# 546

# %%
# display how many element which value equal Zero in revenue column 
df[(df['revenue'] == 0)].shape[0]
# Out:
# 546

# %%
# to calculate out the profits of each movie will subtract from budget
df['profit'] = df['revenue'] - df['budget']
df.tail()
# Out:
#           id  popularity   budget    revenue                   original_title  \
# 10724    668    1.778746  7000000   81974493  On Her Majesty's Secret Service
# 10759    948    1.198849   300000   70000000                        Halloween
# 10760   8469    1.157930  2700000  141000000                     Animal House
# 10817  13963    0.064029        0     321952                   The Last Waltz
# 10819  16214    0.044675        0   78000000                           Hooper
#
#                                                     cast         director  \
# 10724  George Lazenby|Diana Rigg|Telly Savalas|Gabrie...    Peter R. Hunt
# 10759  Donald Pleasence|Jamie Lee Curtis|P.J. Soles|N...   John Carpenter
# 10760  John Belushi|Tim Matheson|John Vernon|Verna Bl...      John Landis
# 10817  Robbie Robertson|Rick Danko|Levon Helm|Richard...  Martin Scorsese
# 10819  Burt Reynolds|Robert Klein|Adam West|Jan-Micha...      Hal Needham
#
#        runtime                     genres  \
# 10724      142  Adventure|Action|Thriller
# 10759       91            Horror|Thriller
# 10760      109                     Comedy
# 10817      117          Documentary|Music
# 10819      107              Action|Comedy
#
#                                     production_companies release_date  \
# 10724   Eon Productions|Metro-Goldwyn-Mayer (MGM)|Danjaq     12/12/69
# 10759  Compass International Pictures|Falcon Internat...     10/25/78
# 10760  Universal Pictures|Oregon Film Factory|Stage I...      7/27/78
# 10817                     FM Productions|Last Waltz Inc.       5/1/78
# 10819                                       Warner Bros.      7/28/78
#
#        vote_count  release_year     profit
# 10724         258          1969   74974493
# 10759         522          1978   69700000
# 10760         230          1978  138300000
# 10817          33          1978     321952
# 10819          13          1978   78000000

# %%
# spliting each string in the Series by sep and return a frame
# of dummy/indicator variables
# then merge them an take the mean as an index occurs
# in more than one
genres_df = df.genres.str.get_dummies(sep='|')
df = df.merge(genres_df, left_index=True, right_index=True)

# %%
# Convert 'release_date' column to datetime
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
# detecting missing values
print(df.isna().sum())
# Out:
# id                      0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# director                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# release_year            0
# profit                  0
# Action                  0
# Adventure               0
# Animation               0
# Comedy                  0
# Crime                   0
# Documentary             0
# Drama                   0
# Family                  0
# Fantasy                 0
# Foreign                 0
# History                 0
# Horror                  0
# Music                   0
# Mystery                 0
# Romance                 0
# Science Fiction         0
# TV Movie                0
# Thriller                0
# War                     0
# Western                 0
# dtype: int64

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# > After that I've trimmed and cleaned your data, I'm ready to move on to exploration. Compute statistics and create visualizations with the goal of addressing the research questions that you posed in the Introduction section. I made it systematic with my approach. Looking at one variable at a time, and then follow it up by looking at relationships between variables.

# %%
# this returns useful descriptive statistics for each column of data
df.describe()
# Out:
#                   id   popularity        budget       revenue      runtime  \
# count    1992.000000  1992.000000  1.992000e+03  1.992000e+03  1992.000000
# mean    71652.152108     1.316763  3.454924e+07  1.152153e+08   106.040161
# std     92355.883915     1.873563  5.061878e+07  2.202887e+08    29.234592
# min        11.000000     0.000620  0.000000e+00  0.000000e+00     0.000000
# 25%      9699.000000     0.384079  0.000000e+00  0.000000e+00    92.000000
# 50%     35112.500000     0.774223  1.500000e+07  2.578782e+07   102.000000
# 75%     83573.000000     1.538639  4.800000e+07  1.278787e+08   116.000000
# max    414419.000000    32.985763  4.250000e+08  2.781506e+09   705.000000
#
#         vote_count  release_year        profit       Action    Adventure  \
# count  1992.000000   1992.000000  1.992000e+03  1992.000000  1992.000000
# mean    643.616968   2007.796687  8.066604e+07     0.267068     0.181225
# std    1092.355998      7.549224  1.855373e+08     0.442539     0.385301
# min      10.000000   1961.000000 -4.139124e+08     0.000000     0.000000
# 25%      51.000000   2006.000000  0.000000e+00     0.000000     0.000000
# 50%     210.000000   2010.000000  5.632296e+06     0.000000     0.000000
# 75%     688.250000   2012.000000  7.794797e+07     1.000000     0.000000
# max    9767.000000   2015.000000  2.544506e+09     1.000000     1.000000
#
#           ...           History       Horror        Music      Mystery  \
# count     ...       1992.000000  1992.000000  1992.000000  1992.000000
# mean      ...          0.028112     0.137048     0.036145     0.074297
# std       ...          0.165336     0.343985     0.186697     0.262320
# min       ...          0.000000     0.000000     0.000000     0.000000
# 25%       ...          0.000000     0.000000     0.000000     0.000000
# 50%       ...          0.000000     0.000000     0.000000     0.000000
# 75%       ...          0.000000     0.000000     0.000000     0.000000
# max       ...          1.000000     1.000000     1.000000     1.000000
#
#            Romance  Science Fiction     TV Movie     Thriller          War  \
# count  1992.000000      1992.000000  1992.000000  1992.000000  1992.000000
# mean      0.146084         0.146084     0.008032     0.288655     0.022088
# std       0.353279         0.353279     0.089284     0.453251     0.147008
# min       0.000000         0.000000     0.000000     0.000000     0.000000
# 25%       0.000000         0.000000     0.000000     0.000000     0.000000
# 50%       0.000000         0.000000     0.000000     0.000000     0.000000
# 75%       0.000000         0.000000     0.000000     1.000000     0.000000
# max       1.000000         1.000000     1.000000     1.000000     1.000000
#
#            Western
# count  1992.000000
# mean      0.010040
# std       0.099721
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000
#
# [8 rows x 28 columns]

# %%
# detecting to know number of each column
{df.columns.get_loc(c):c for idx, c in enumerate(df.columns)}
# Out:
# {0: 'id',
#  1: 'popularity',
#  2: 'budget',
#  3: 'revenue',
#  4: 'original_title',
#  5: 'cast',
#  6: 'director',
#  7: 'runtime',
#  8: 'genres',
#  9: 'production_companies',
#  10: 'release_date',
#  11: 'vote_count',
#  12: 'release_year',
#  13: 'profit',
#  14: 'Action',
#  15: 'Adventure',
#  16: 'Animation',
#  17: 'Comedy',
#  18: 'Crime',
#  19: 'Documentary',
#  20: 'Drama',
#  21: 'Family',
#  22: 'Fantasy',
#  23: 'Foreign',
#  24: 'History',
#  25: 'Horror',
#  26: 'Music',
#  27: 'Mystery',
#  28: 'Romance',
#  29: 'Science Fiction',
#  30: 'TV Movie',
#  31: 'Thriller',
#  32: 'War',
#  33: 'Western'}

# %% [markdown]
# ### Research Question 1 (What are ten movies Vs highest profit for each one?)

# %%
# ordering table by profit with only the specific columns
data = df.groupby(['profit', 'original_title'], as_index=False)['id', 'popularity', 'revenue', 'runtime', 'release_year'].sum()
data.tail(10)
# Out:
#           profit                                original_title      id  \
# 1982  1082730962                                       Minions  211672
# 1983  1124219009                                        Frozen  109445
# 1984  1125035767                       Avengers: Age of Ultron   99861
# 1985  1202817822  Harry Potter and the Deathly Hallows: Part 2   12445
# 1986  1299557910                                  The Avengers   24428
# 1987  1316249360                                     Furious 7  168259
# 1988  1363528810                                Jurassic World  135397
# 1989  1645034188                                       Titanic     597
# 1990  1868178225                  Star Wars: The Force Awakens  140607
# 1991  2544505847                                        Avatar   19995
#
#       popularity     revenue  runtime  release_year
# 1982    7.404165  1156730962       91          2015
# 1983    6.112766  1274219009      102          2013
# 1984    5.944927  1405035767      141          2015
# 1985    5.711315  1327817822      130          2011
# 1986    7.637767  1519557910      143          2012
# 1987    9.335014  1506249360      137          2015
# 1988   32.985763  1513528810      124          2015
# 1989    4.355219  1845034188      194          1997
# 1990   11.173104  2068178225      136          2015
# 1991    9.432768  2781505847      162          2009

# %%
# arranging by highest value
counts = data.groupby(['profit', 'original_title'], as_index=False)['runtime'].sum().tail(10)
counts = counts.sort_values(by='profit', ascending = False)
counts
# Out:
#           profit                                original_title  runtime
# 1991  2544505847                                        Avatar      162
# 1990  1868178225                  Star Wars: The Force Awakens      136
# 1989  1645034188                                       Titanic      194
# 1988  1363528810                                Jurassic World      124
# 1987  1316249360                                     Furious 7      137
# 1986  1299557910                                  The Avengers      143
# 1985  1202817822  Harry Potter and the Deathly Hallows: Part 2      130
# 1984  1125035767                       Avengers: Age of Ultron      141
# 1983  1124219009                                        Frozen      102
# 1982  1082730962                                       Minions       91

# %%
# grouping a DataFrame by a column then each unique value
count = counts.groupby('profit')['original_title'].sum()

# %%
# creating a bar chart for profit and orginal title
df = pd.DataFrame(count.index, count.values);
ax = df.plot.barh(rot=0)

ax.set_title('10 Most Profitable each of movie')
ax.set_xlabel('Profit')
ax.set_ylabel('Orginal Title');
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False);
ax.spines['left'].set_visible(False)

# %% [markdown]
# > We note `Avatar` movie is top one of profit where is more than billion and half.

# %% [markdown]
# ### Research Question 2  (What is year has the muchest recording of movies?)

# %%
# make group for each year and count the number of
# movies in each year
count_movie = df.groupby('release_year')['id'].count()
print(count_movie.tail(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-0fb0d75a3fc3> in <module>
#       1 # make group for each year and count the number of
#       2 # movies in each year
# ----> 3 count_movie = df.groupby('release_year')['id'].count()
#       4 print(count_movie.tail(10))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'release_year'

# %%
# creating a graph chart for number of movies vs each year
fig,ax= plt.subplots(figsize=(5, 5));
ax.plot(count_movie.index, count_movie.values); # data.index : x , data.values : y

ax.set_title('Year Vs Number Of Movies')
ax.set_xlabel('Relese Year')
ax.set_ylabel('Number Of Movies');
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
# arranging by highest value
counts = data.groupby(['runtime', 'original_title'], as_index=False)['id'].sum()
counts = counts.sort_values(by='runtime', ascending = False)
counts.head(1)
# Out:
#       runtime    original_title      id
# 1991      705  Band of Brothers  331214

# %%
# arranging by highest value
counts = data.groupby(['revenue', 'original_title'], as_index=False)['id'].sum()
counts = counts.sort_values(by='revenue', ascending = False)
counts.head(1)
# Out:
#          revenue original_title     id
# 1989  2781505847         Avatar  19995

# %%
# make group for each year and count the number of
# movies in each year
count_movie = df.groupby('release_year')['id'].count()
count_movie.tail(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-bf18f7b0909b> in <module>
#       1 # make group for each year and count the number of
#       2 # movies in each year
# ----> 3 count_movie = df.groupby('release_year')['id'].count()
#       4 count_movie.tail(10)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'release_year'
